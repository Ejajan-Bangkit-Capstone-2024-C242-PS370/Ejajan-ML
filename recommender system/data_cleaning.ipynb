# %%
import pandas as pd
import numpy as  np

# %%
data = pd.read_csv('./data/recipes.csv')

# %%
data.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# ...

# %%
data.shape
# Out:
# (522517, 28)

# %%
dataset=data.copy()
columns=['Name', 'RecipeIngredientParts',
         'Calories', 'FatContent', 'SaturatedFatContent',
         'CholesterolContent', 'SodiumContent', 'CarbohydrateContent',
         'FiberContent','SugarContent','ProteinContent'
         ]
dataset=dataset[columns]

# %%
max_Calories=2650
max_daily_fat=100
max_daily_Saturatedfat=13
max_daily_Cholesterol=300
max_daily_Sodium=2300
max_daily_Carbohydrate=325
max_daily_Fiber=40
max_daily_Sugar=40
max_daily_Protein=200
max_list=[max_Calories,
          max_daily_fat,
          max_daily_Saturatedfat,
          max_daily_Cholesterol,
          max_daily_Sodium,
          max_daily_Carbohydrate,
          max_daily_Fiber,
          max_daily_Sugar,
          max_daily_Protein]

# %%
extracted_data=dataset.copy()
for column,maximum in zip(extracted_data.columns[6:15],max_list):
    extracted_data=extracted_data[extracted_data[column]<maximum]

# %%
extracted_data.shape
# Out:
# (461945, 11)

# %%
extracted_data = extracted_data.dropna(axis=0)

# %%
extracted_data.shape
# Out:
# (461945, 11)

# %%
extracted_data.head()
# Out:
#                                 Name  \
# 0  Low-Fat Berry Blue Frozen Dessert
# 1                            Biryani
# 2                      Best Lemonade
# 4                       Cabbage Soup
# 5               Best Blackbottom Pie
#
#                                RecipeIngredientParts  Calories  FatContent  \
# 0  c("blueberries", "granulated sugar", "vanilla ...     170.9         2.5
# 1  c("saffron", "milk", "hot green chili peppers"...    1110.7        58.8
# 2  c("sugar", "lemons, rind of", "lemon, zest of"...     311.1         0.2
# 4  c("plain tomato juice", "cabbage", "onion", "c...     103.6         0.4
# 5  c("graham cracker crumbs", "sugar", "butter", ...     437.9        19.3
#
#    SaturatedFatContent  CholesterolContent  SodiumContent  \
# 0                  1.3                 8.0           29.8
# 1                 16.6               372.8          368.4
# 2                  0.0                 0.0            1.8
# ...

# %%
def convert_to_list(r_string):
    # Menghapus `c(` dan tanda kurung di awal dan akhir
    cleaned = r_string.replace('c(', '').strip(')')
    # Memisahkan elemen berdasarkan koma dan menghapus spasi atau tanda kutip
    return ', '.join([item.strip().strip('"') for item in cleaned.split(',')])

# Terapkan fungsi ke kolom 'ingredients'
extracted_data['Ingredients'] = extracted_data['RecipeIngredientParts'].apply(convert_to_list)

# %%
extracted_data.head()
# Out:
#                                 Name  \
# 0  Low-Fat Berry Blue Frozen Dessert
# 1                            Biryani
# 2                      Best Lemonade
# 4                       Cabbage Soup
# 5               Best Blackbottom Pie
#
#                                RecipeIngredientParts  Calories  FatContent  \
# 0  c("blueberries", "granulated sugar", "vanilla ...     170.9         2.5
# 1  c("saffron", "milk", "hot green chili peppers"...    1110.7        58.8
# 2  c("sugar", "lemons, rind of", "lemon, zest of"...     311.1         0.2
# 4  c("plain tomato juice", "cabbage", "onion", "c...     103.6         0.4
# 5  c("graham cracker crumbs", "sugar", "butter", ...     437.9        19.3
#
#    SaturatedFatContent  CholesterolContent  SodiumContent  \
# 0                  1.3                 8.0           29.8
# 1                 16.6               372.8          368.4
# 2                  0.0                 0.0            1.8
# ...

# %%
detect_allergen = extracted_data['Ingredients'].unique()
print(detect_allergen)
# Out:
# ['blueberries, granulated sugar, vanilla yogurt, lemon juice'
#  'saffron, milk, hot green chili peppers, onions, garlic, clove, peppercorns, cardamom seed, cumin seed, poppy seed, mace, cilantro, mint leaf, fresh lemon juice, plain yogurt, boneless chicken, salt, ghee, onion, tomatoes, basmati rice, long-grain rice, raisins, cashews, eggs'
#  'sugar, lemons, rind of, lemon, zest of, fresh water, fresh lemon juice'
#  ... 'Dijon mustard, garlic, peppercorns, shallot, cognac, brandy'
#  'half-and-half, heavy cream, brandy, sugar'
#  'hard-boiled eggs, breakfast sausage, panko breadcrumbs, Worcestershire sauce, flour, panko breadcrumbs, water']

# %%
# Define allergen categories and keywords
allergen_keywords = {
    "Dairy": ["milk", "cheese", "butter", "cream", "yogurt"],
    "Nuts": ["pecan", "almond", "peanut", "hazelnut"],
    "Gluten": ["flour", "bread", "oats", "barley", "wheat"],
    "Eggs": ["egg", "egg whites"],
    "Soy": ["soy", "tofu", "soy sauce"],
    "Seafood": ["fish", "shrimp", "crab", "shellfish"],
    "Sesame": ["sesame", "tahini"],
    "Sulphites": ["sulphites", "vinegar"],
    "Legumes": ["peanuts", "lentils", "beans"]
}

def potential_allergens(ingredients):
    allergens = []
    for key, values in allergen_keywords.items():
        for value in values:
            if value in ingredients:
                allergens.append(key)
    return ", ".join(allergens) if allergens else "None"

# Application to dataset
extracted_data['Allergens'] = extracted_data['Ingredients'].apply(potential_allergens)

# View the dataset with allergens
extracted_data.head()
# Out:
#                                 Name  \
# 0  Low-Fat Berry Blue Frozen Dessert
# 1                            Biryani
# 2                      Best Lemonade
# 4                       Cabbage Soup
# 5               Best Blackbottom Pie
#
#                                RecipeIngredientParts  Calories  FatContent  \
# 0  c("blueberries", "granulated sugar", "vanilla ...     170.9         2.5
# 1  c("saffron", "milk", "hot green chili peppers"...    1110.7        58.8
# 2  c("sugar", "lemons, rind of", "lemon, zest of"...     311.1         0.2
# 4  c("plain tomato juice", "cabbage", "onion", "c...     103.6         0.4
# 5  c("graham cracker crumbs", "sugar", "butter", ...     437.9        19.3
#
#    SaturatedFatContent  CholesterolContent  SodiumContent  \
# 0                  1.3                 8.0           29.8
# 1                 16.6               372.8          368.4
# 2                  0.0                 0.0            1.8
# ...

# %%
extracted_data.to_csv('cleaned_recipes.csv', index=False)
